# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from prophet import Prophet
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

train = pd.read_csv('./train.csv')
# 결과를 저장하기 위한 dataframe 생성
results_df = pd.DataFrame(columns=['종목코드', 'final_return'])

# train 데이터에 존재하는 독립적인 종목코드 추출
unique_codes = train['종목코드'].unique()

# 과거 데이터를 기반으로 데이터프레임을 구성하는 함수
def create_features(df, n_days):
    df_new = df.copy()
    for i in range(1, n_days+1):
        df_new[f'종가_lag_{i}'] = df_new['종가'].shift(i)
    df_new.dropna(inplace=True)
    return df_new

# 각 종목코드에 대해서 모델 학습 및 추론 반복
for code in tqdm(unique_codes):
    
    # 학습 데이터 생성
    train_data = train[train['종목코드'] == code][['일자', '종가']]
    train_data['일자'] = pd.to_datetime(train_data['일자'], format='%Y%m%d')
    train_data.set_index('일자', inplace=True)
    
    # Prophet 모델 학습 및 추론
    df = train_data.reset_index().rename(columns={'일자':'ds', '종가':'y'})
    model_prophet = Prophet()
    model_prophet.fit(df)
    future = model_prophet.make_future_dataframe(periods=15)
    forecast = model_prophet.predict(future)
    final_return_prophet = (forecast['yhat'].values[-1] - forecast['yhat'].values[-15]) / forecast['yhat'].values[-15]
    
    # Gradient Boosting 모델 학습 및 추론
    train_data = create_features(train_data, 5)
    X = train_data.drop('종가', axis=1).values
    y = train_data['종가'].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
    model_gb = XGBRegressor(n_estimators=100, learning_rate=0.1)
    model_gb.fit(X_train, y_train)
    predictions = []
    X_last = X_test[-1, :]
    for _ in range(15):
        pred = model_gb.predict(X_last.reshape(1, -1))
        predictions.append(pred[0])
        X_last = np.roll(X_last, -1)
        X_last[-1] = pred
    final_return_gb = (predictions[-1] - predictions[0]) / predictions[0]
    
    # 두 모델의 결과를 앙상블
    final_return = (final_return_prophet + final_return_gb) / 2
    
    # 결과 저장
    results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)

# 각 순위를 중복없이 생성
results_df['순위'] = results_df['final_return'].rank(method='first', ascending=False).astype('int')
results_df
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]01:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:41 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 1/2000 [00:00<23:24,  1.42it/s]01:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:42 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 2/2000 [00:01<21:10,  1.57it/s]01:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:43 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 3/2000 [00:02<22:20,  1.49it/s]01:09:43 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:43 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 4/2000 [00:02<21:09,  1.57it/s]01:09:44 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:44 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 5/2000 [00:03<22:21,  1.49it/s]01:09:44 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:44 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 6/2000 [00:03<21:18,  1.56it/s]01:09:45 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:45 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 7/2000 [00:04<20:41,  1.61it/s]01:09:45 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:46 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 8/2000 [00:05<20:20,  1.63it/s]01:09:46 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:46 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 9/2000 [00:05<19:47,  1.68it/s]01:09:47 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:47 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 10/2000 [00:06<20:00,  1.66it/s]01:09:47 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:47 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   1%|          | 11/2000 [00:06<19:48,  1.67it/s]01:09:48 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:48 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   1%|          | 12/2000 [00:07<19:39,  1.69it/s]01:09:48 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:48 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   1%|          | 13/2000 [00:07<19:11,  1.73it/s]01:09:49 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:49 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   1%|          | 14/2000 [00:08<18:50,  1.76it/s]01:09:49 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:50 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   1%|          | 15/2000 [00:09<18:23,  1.80it/s]01:09:50 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:50 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   1%|          | 16/2000 [00:09<18:10,  1.82it/s]01:09:51 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:51 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   1%|          | 17/2000 [00:10<18:20,  1.80it/s]01:09:51 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:51 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   1%|          | 18/2000 [00:10<19:00,  1.74it/s]01:09:52 - cmdstanpy - INFO - Chain [1] start processing
# 01:09:52 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   1%|          | 19/2000 [00:11<18:43,  1.76it/s]01:09:52 - cmdstanpy - INFO - Chain [1] start processing
# 01:09
- cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1977/2000 [18:42<00:13,  1.76it/s]01:28:23 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:23 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1978/2000 [18:42<00:12,  1.79it/s]01:28:24 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:24 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1979/2000 [18:43<00:12,  1.72it/s]01:28:24 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:24 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1980/2000 [18:43<00:11,  1.75it/s]01:28:25 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:25 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1981/2000 [18:44<00:10,  1.78it/s]01:28:25 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:26 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1982/2000 [18:45<00:09,  1.82it/s]01:28:26 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:26 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1983/2000 [18:45<00:09,  1.78it/s]01:28:27 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:27 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1984/2000 [18:46<00:09,  1.76it/s]01:28:27 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:27 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1985/2000 [18:46<00:08,  1.77it/s]01:28:28 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:28 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1986/2000 [18:47<00:08,  1.74it/s]01:28:28 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:28 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1987/2000 [18:47<00:07,  1.76it/s]01:28:29 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:29 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1988/2000 [18:48<00:06,  1.75it/s]01:28:29 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:30 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#  99%|█████████▉| 1989/2000 [18:49<00:06,  1.80it/s]01:28:30 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:30 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1990/2000 [18:49<00:05,  1.81it/s]01:28:30 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:31 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1991/2000 [18:50<00:05,  1.77it/s]01:28:31 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:31 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1992/2000 [18:50<00:04,  1.75it/s]01:28:32 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:32 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1993/2000 [18:51<00:04,  1.74it/s]01:28:32 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:32 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1994/2000 [18:51<00:03,  1.74it/s]01:28:33 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:33 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1995/2000 [18:52<00:02,  1.80it/s]01:28:33 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:34 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1996/2000 [18:52<00:02,  1.77it/s]01:28:34 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:34 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1997/2000 [18:53<00:01,  1.76it/s]01:28:35 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:35 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1998/2000 [18:54<00:01,  1.77it/s]01:28:35 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:35 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|█████████▉| 1999/2000 [18:54<00:00,  1.80it/s]01:28:36 - cmdstanpy - INFO - Chain [1] start processing
# 01:28:36 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_30583/3013389176.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
# 100%|██████████| 2000/2000 [18:55<00:00,  1.76it/s]
#          종목코드  final_return    순위
# 0     A060310     -0.145520  1991
# 1     A095570     -0.010874  1641
# 2     A006840      0.053218    97
# 3     A054620     -0.007791  1556
# 4     A265520      0.010359   762
# ...       ...           ...   ...
# 1995  A189980      0.001354  1171
# 1996  A000540     -0.000077  1251
# 1997  A003280     -0.010531  1635
# 1998  A037440      0.053064    98
# 1999  A238490      0.041356   161
#
# [2000 rows x 3 columns]

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission
# Out:
#          종목코드    순위
# 0     A000020     1
# 1     A000040     2
# 2     A000050     3
# 3     A000070     4
# 4     A000080     5
# ...       ...   ...
# 1995  A375500  1996
# 1996  A378850  1997
# 1997  A383220  1998
# 1998  A383310  1999
# 1999  A383800  2000
#
# [2000 rows x 2 columns]

# %%
baseline_submission = sample_submission[['종목코드']].merge(results_df[['종목코드', '순위']], on='종목코드', how='left')
baseline_submission
# Out:
#          종목코드    순위
# 0     A000020  1711
# 1     A000040  1030
# 2     A000050   840
# 3     A000070   538
# 4     A000080  1531
# ...       ...   ...
# 1995  A375500  1206
# 1996  A378850   155
# 1997  A383220   396
# 1998  A383310  1446
# 1999  A383800  1361
#
# [2000 rows x 2 columns]

# %%
baseline_submission.to_csv('ProphetGBEnsenble_submission.csv', index=False)
