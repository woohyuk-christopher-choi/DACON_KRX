# %%
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]/var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_49537/3068018276.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 1/2000 [00:08<4:33:09,  8.20s/it]/var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_49537/3068018276.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'종목코드': code, 'final_return': final_return}, ignore_index=True)
#   0%|          | 2/2000 [00:09<2:22:47,  4.29s/it]/var/folders/8l/d0_bj06x2czf46y6_p5zswgr0000gn/T/ipykernel_49537/3068018276.py:65: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
